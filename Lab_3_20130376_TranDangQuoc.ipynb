# %% [markdown]
# <a href="https://colab.research.google.com/github/couqdev/MachineLearning/blob/main/Lab_3_20130376_TranDangQuoc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Deadline: 23:59, 04/03/2023**

# %% [markdown]
# # Task 1.
# The main aim of this task is to get familiar with the tasks of preprocessing data using Scikit-learn – a Python-based Machine Learning framework and Linear Regression.

# %% [markdown]
# For given 2 datasets (preprocessing_weather.csv, preprocessing_salary_dummy.csv),
# *   Identify issues with these datasets
# *   Then, apply preprocessing techniques to the datasets

# %% [markdown]
# #Task 1.1. Dataset preprocessing_weather.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/MachineLeaning'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/MachineLeaning

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Preprocessing dataset**:

# %%
#code
dataset1 = pd.read_csv("preprocessing_weather.csv")
imputer = SimpleImputer(missing_values=np.NaN, strategy='median')
# X = dataset1.iloc[:,2:4].values
# imputer.fit_transform(X)
dataset1['temperature'] = imputer.fit_transform(dataset1['temperature'].values.reshape(-1, 1))
dataset1['humidity'] = imputer.fit_transform(dataset1['humidity'].values.reshape(-1, 1))
dataset1
# Out:
#     id   outlook  temperature  humidity  windy play
# 0    1     sunny         85.0      85.0  False   no
# 1    2     sunny         80.0      90.0   True   no
# 2    3  overcast         83.0      86.0  False  yes
# 3    4     rainy         72.0      96.0  False  yes
# 4    5     rainy         68.0      80.0  False  yes
# 5    6     rainy         65.0      70.0   True   no
# 6    7  overcast         64.0      65.0   True  yes
# 7    8     sunny         72.0      95.0  False   no
# 8    9     sunny         69.0      85.0  False  yes
# 9   10     rainy         75.0      80.0  False  yes
# 10  11     sunny         75.0      70.0   True  yes
# 11  12  overcast         72.0      90.0   True  yes
# 12  13  overcast         81.0      75.0  False  yes
# 13  14     rainy         71.0      91.0   True   no

# %% [markdown]
# #Task 1.2. Dataset preprocessing_salary_dummy.csv

# %% [markdown]
# **Issues**:
#
#
# 1.   List item
# 2.   List item
# 3.   List item
# 4.   List item
# ....

# %% [markdown]
# **Preprocessing dataset**:

# %%
#code
dataset2 = pd.read_csv("preprocessing_salary_dummy.csv")
imputer2 = SimpleImputer(missing_values=np.NaN, strategy='median')
# # X = dataset2.iloc[:,2:4].values
# # imputer2.fit_transform(X)
dataset2[' Age'] = imputer2.fit_transform(dataset2[' Age'].values.reshape(-1,1))
dataset2['   Salary '] = imputer2.fit_transform(dataset2['   Salary '].values.reshape(-1, 1))
dataset2
# Out:
#    No    Country   Age     Salary  Purchased
# 0   1     France  44.0     72000.0        No
# 1   2      Spain  27.0     48000.0       Yes
# 2   3    Germany  30.0     54000.0        No
# 3   4      Spain  38.0     61000.0        No
# 4   5    Germany  40.0     61000.0       Yes
# 5   6     France  35.0     58000.0       Yes
# 6   7      Spain  38.0     52000.0        No
# 7   8     France  48.0     79000.0       Yes
# 8   9    Germany  50.0     83000.0        No
# 9  10     France  37.0     67000.0       Yes

# %% [markdown]
# # **Task 2**. Simple Linear Regression in Scikit-Learn
# ---
# # **Usage:**
# > **Step 1**: build a model
# ![image.png](data:image/png;base64,...)
#
# > **Step 2**: test the model
#
# *   With test set:
# `y_pred = regressor.predict(X_test)`
#
# *   With a single value ("predict" method always expects a 2D array as the format of its inputs)
# `regressor.predict([[12]])`
#
# > **Step 3**:
# *   get w0, w1 , w2, …,
# -- W0: `regressor.intercept_`
# -- w1, w2, …: `regressor.coef_`
# *   R^2 score: sum of squared r(i)
# `r(i) = y(i) - f(x(i))`: residual of ith instance
#
#
# > **Metrics**:
# *   metrics.explained_variance_score(y_test, y_pred)
# *   metrics.mean_absolute_error(y_ test, y_pred)
# *   metrics.mean_squared_error(y_ test, y_pred[, ...])
# *   metrics.mean_squared_log_error(y_ test, y_pred)
# *   metrics.median_absolute_error(y_ test, y_pred)
# *   metrics.r2_score(y_ test, y_pred[, ...])

# %% [markdown]
# ---

# %% [markdown]
# # Tasks
# The main aim of these tasks is to get familiar with Linear Regression problems. Apply LinearRegression to the following datasets. Note the error obtained and coefficients
# *   **dataset1.csv** - a synthetic dataset including 5 points (1-dimensional data) with one target
# *   **dataset2.csv** - a synthetic dataset including 1000 points (3-dimensional data) with one target variable. The variables are named x1, x2, x3, y. y is the variable to be regressed. Split the dataset into training set and test set (70% for training set and 30% for test set).

# %% [markdown]
# # Task 2.1. dataset1.csv

# %%
#code
data1 = pd.read_csv("dataset1.csv")

X_train = data1[['x']]
y_train = data1[['y']]

regressor = LinearRegression()

regressor.fit(X_train, y_train)

print(regressor.intercept_)
print("------------------------")
print(regressor.coef_)
print("------------------------")
y_pred = regressor.predict(X_train)
print(y_pred)
print("------------------------")
r2 = metrics.r2_score(y_train, y_pred)
print(r2)
# Out:
# [0.4]
# ------------------------
# [[0.8]]
# ------------------------
# [[1.2]
#  [2. ]
#  [3.6]
#  [2.8]
#  [4.4]]
# ------------------------
# 0.7272727272727273

# %% [markdown]
# # Task 2.2. dataset2.csv

# %%
#code
data2 = pd.read_csv("dataset2.csv")

X = data2[['x1','x2','x3']]
y = data2[['y']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

regressor = LinearRegression()

regressor.fit(X_train, y_train)

print(regressor.intercept_)
print("------------------------")
print(regressor.coef_)
print("------------------------")
y_pred = regressor.predict(X_train)
print(y_pred)
print("------------------------")
r2 = metrics.r2_score(y_train, y_pred)
print(r2)
# Out:
# [4.00002045]
# ------------------------
# [[2.99999593 3.99999565 4.99999157]]
# ------------------------
# [[-6.76784491e+00]
#  [ 3.44856302e+00]
#  [-6.16316756e+00]
#  [-6.82171836e+00]
#  [-1.56468042e+01]
#  [ 1.35161281e+01]
#  [ 7.67143692e+00]
#  [-2.40507572e+00]
#  [ 5.36431910e+00]
#  [-4.85346722e+00]
#  [-1.32011811e+01]
#  [ 4.31525371e+00]
#  [ 4.57064752e+00]
#  [ 1.02676913e+01]
#  [ 1.22194444e+01]
#  [ 7.42820781e+00]
#  [-7.28432152e+00]
#  [-6.73674273e+00]
#  [ 3.81041536e+00]
#  [ 4.13721837e+00]
#  [ 3.22156759e+00]
#  [ 1.43284777e+00]
#  [-1.75846666e+00]
#  [ 5.55149839e+00]
#  [ 1.68911705e+01]
#  [ 5.01573386e+00]
#  [ 3.58559975e+00]
#  [ 5.05492885e+00]
#  [ 2.03432977e+01]
#  [-7.82071301e-01]
#  [-9.45976123e+00]
#  [ 1.20953222e+01]
#  [-6.80541474e+00]
#  [ 7.43855450e-01]
#  [-8.30723246e+00]
#  [ 1.53651537e+01]
#  [-7.62761722e+00]
#  [-5.17697182e+00]
#  [-1.05885839e+01]
#  [ 1.61358213e+01]
#  [ 6.76902929e+00]
#  [ 1.18867371e+01]
#  [-4.45444606e+00]
#  [ 9.38791287e+00]
#  [ 1.07433652e+01]
#  [ 8.85531773e+00]
#  [-9.77201405e+00]
#  [ 9.99960537e+00]
#  [-3.96572637e+00]
#  [-1.54642531e+01]
#  [ 1.51903957e+01]
#  [-1.73810500e+01]
#  [ 5.20546920e+00]
#  [-1.20237563e+01]
#  [ 3.38086486e+00]
#  [ 1.50865436e+01]
#  [ 4.85460187e+00]
#  [ 7.80986820e+00]
#  [ 1.60238641e+01]
#  [ 1.60925035e+01]
#  [ 7.51261011e+00]
#  [ 8.22015071e+00]
#  [ 1.38668838e+01]
#  [ 1.21797097e+01]
#  [-1.12352674e+01]
#  [-1.09221946e+01]
#  [ 7.49384278e-01]
#  [ 4.39392355e+00]
#  [ 4.95269436e+00]
#  [ 1.27412031e+01]
#  [ 1.79003968e+01]
#  [-1.21684183e+01]
#  [-9.20796063e+00]
#  [ 1.39046642e+00]
#  [ 8.53182007e+00]
#  [ 1.72740979e+01]
#  [ 1.95649674e+01]
#  [ 7.45871177e+00]
#  [ 1.83001026e+01]
#  [ 4.25493812e+00]
#  [ 1.14294271e+01]
#  [-3.12073956e+00]
#  [ 1.90834008e+01]
#  [ 1.62023544e+01]
#  [ 5.88951456e+00]
#  [-1.29381337e+01]
#  [ 6.15405233e+00]
#  [-6.34756458e+00]
#  [ 3.55611492e+00]
#  [ 3.50070361e+00]
#  [ 8.93081767e+00]
#  [-1.48871933e+01]
#  [-8.96311443e+00]
#  [-1.91123776e+00]
#  [-4.98282135e+00]
#  [ 9.32609614e+00]
#  [ 6.01957775e+00]
#  [ 1.24683347e+01]
#  [ 9.63147075e+00]
#  [ 4.91886042e+00]
#  [-7.36668091e-01]
#  [ 6.39577853e+00]
#  [ 1.34040040e+01]
#  [-9.60021766e+00]
#  [ 2.10735752e+01]
#  [ 1.68446561e+01]
#  [ 1.16877947e+01]
#  [ 1.54420738e+01]
#  [ 1.03283130e+01]
#  [ 1.05538686e+00]
#  [ 1.11183127e+01]
#  [ 1.92805553e+01]
#  [-1.16708527e+00]
#  [-7.68626111e+00]
#  [-3.89617423e+00]
#  [ 2.27759936e+01]
#  [-1.86792150e-01]
#  [ 1.84040391e+01]
#  [ 1.73610018e+01]
#  [-1.09247572e+01]
#  [ 1.17404127e+01]
#  [ 3.77697385e+00]
#  [ 2.03650978e+01]
#  [ 6.69215663e+00]
#  [ 4.82050248e-01]
#  [ 3.01260436e+00]
#  [ 1.12647778e+01]
#  [-5.50856639e+00]
#  [-1.03757107e+01]
#  [ 1.00300790e+00]
#  [ 3.09794195e+00]
#  [-3.11923497e+00]
#  [ 2.31680049e+00]
#  [ 1.45617008e+01]
#  [ 2.96401848e+01]
#  [ 1.05693062e+01]
#  [ 1.32171765e+00]
#  [ 1.47169549e+01]
#  [-1.06672308e+00]
#  [ 7.50391259e+00]
#  [ 1.06774947e+01]
#  [ 3.03051547e+00]
#  [ 3.98345561e+00]
#  [ 1.55104161e+01]
#  [ 1.95959870e+01]
#  [ 6.48782299e+00]
#  [-5.15630700e+00]
#  [ 2.27463940e+01]
#  [-5.72136660e+00]
#  [-3.43868047e+00]
#  [ 1.49599001e+01]
#  [-8.14250532e+00]
#  [ 9.12491148e+00]
#  [ 1.15347731e+01]
#  [-5.34868405e+00]
#  [-1.59434508e+01]
#  [ 2.44905580e+00]
#  [-3.61040990e+00]
#  [ 2.05870496e+01]
#  [ 1.12386644e+01]
#  [ 7.50951167e+00]
#  [ 3.58416430e+00]
#  [-7.89561270e+00]
#  [-6.86345172e+00]]
# ------------------------
# 0.999999999398945

# %% [markdown]
# # Task 2.3. Apply LinearRegression to the following dataset:
# *   Red wine quality: https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv . The dataset includes info about the chemical properties of different types of wine and how they relate to overall quality.

# %%
#code
dataset = pd.read_csv('Task3_winequality-red.csv', sep=';')



# sc = StandardScaler()
X = dataset[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol']]
y = dataset[['quality']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

regressor1 = LinearRegression()

regressor1.fit(X_train, y_train)

print(regressor1.intercept_)
print("------------------------")
print(regressor1.coef_)
print("------------------------")
y_pred = regressor1.predict(X_train)
print(y_pred)
print("------------------------")
r2 = metrics.r2_score(y_train, y_pred)
print(r2)
# Out:
# [40.44622602]
# ------------------------
# [[ 4.79622779e-02 -1.11840142e+00 -2.76227524e-01  2.04756941e-02
#   -1.76890728e+00  5.34980397e-03 -3.44870744e-03 -3.67102234e+01
#   -3.47701478e-01  9.29729469e-01  2.66278221e-01]]
# ------------------------
# [[5.27091129]
#  [5.72219324]
#  [6.97194285]
#  ...
#  [5.4052491 ]
#  [5.07120567]
#  [6.53188855]]
# ------------------------
# 0.3655849921479044

# %% [markdown]
# # Task 2.4. Apply LinearRegression to the following dataset:
# *   Energy efficiency: https://archive.ics.uci.edu/ml/datasets/Energy+efficiency.

# %%
#code
data = pd.read_excel('Task4_ENB2012_data.xlsx')

X = data[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']]
y = data[['Y1', 'Y2']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)
regressor1.fit(X_train, y_train)

print(regressor1.intercept_)
print("------------------------")
print(regressor1.coef_)
print("------------------------")
y_pred = regressor1.predict(X_train)
print(y_pred)
print("------------------------")
r2 = metrics.r2_score(y_train, y_pred)
print(r2)

# data
# Out:
# [81.39324369 98.44986971]
# ------------------------
# [[-6.37286002e+01 -8.12517595e+10  8.12517595e+10  1.62503519e+11
#    4.26273978e+00  1.18152044e-02  1.97247948e+01  2.46080644e-01]
#  [-7.05912105e+01 -1.36127313e+12  1.36127313e+12  2.72254625e+12
#    4.28099442e+00  1.88266629e-01  1.46377981e+01  9.15057063e-02]]
# ------------------------
# [[17.4610063  19.49504233]
#  [18.31226633 19.27174815]
#  [29.94733916 32.48457587]
#  ...
#  [ 7.81283595 12.23089159]
#  [12.43027349 15.4452086 ]
#  [ 8.80921602 12.9888727 ]]
# ------------------------
# 0.9073279171397681

# %% [markdown]
# # Finally,
# Save a copy in your Github. Remember renaming the notebook.
